# %%
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join


pd.set_option('display.max_columns', 500)

# %% [markdown]
# # List all files from parquet

# %%
mypath = 'datas//sentiment_labels'

df = pd.read_parquet("datas//sentiment_labels//NGG_sentiment_label.parquet")

# %%
df.head()
# Out:
#   date_published                                              title  \
# 0     2024-09-21  Kepler Capital Sticks to Their Buy Rating for ...
# 1     2024-09-19  Fed Trims Rates by 50 bps: 3 Utilities to Add ...
# 2     2024-09-17  Striim 5.0 Previews Cutting-Edge Real-Time Dat...
# 3     2024-09-13  Japan's Sumitomo Corporation enters renewable ...
# 4     2024-09-13  Balfour Beatty Wins GBP 363 Mln Contract From ...
#
#                                                  url      time_published  \
# 0  https://markets.businessinsider.com/news/stock... 2024-09-21 23:46:30
# 1  https://www.zacks.com/commentary/2338355/fed-t... 2024-09-19 13:17:00
# 2  https://www.benzinga.com/pressreleases/24/09/g... 2024-09-17 11:00:00
# 3  https://www.business-standard.com/companies/ne... 2024-09-13 13:48:24
# 4  https://markets.businessinsider.com/news/stock... 2024-09-13 07:30:08
#
#                          authors  \
# 0                     [Tipranks]
# 1                   [Jewel Saha]
# ...

# %%
mypath = 'datas//sentiment_labels'

onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
tickers = [i.split("_")[0] for i in onlyfiles]

cols_use = ['date_published', 'title', 'time_published', 'authors',
       'summary', 'source', "ticker", 'label_close2max', 'label_close3max',
       'label_close2min', 'label_close3min', 'label_close2mean', 'label_close3mean',
       'inc_close2mean_perc5', 'inc_close2mean_perc10', 'inc_close2mean_perc3',
       'inc_close2max_perc5', 'inc_close2max_perc10', 'inc_close2max_perc3',
       'inc_close3mean_perc5', 'inc_close3mean_perc10', 'inc_close3mean_perc3',
       'inc_close3max_perc5', 'inc_close3max_perc10', 'inc_close3max_perc3',
       'dec_close2mean_perc5','dec_close2mean_perc10', 'dec_close2mean_perc3', 
       'dec_close2min_perc5', 'dec_close2min_perc10', 'dec_close2min_perc3', 
       'dec_close3mean_perc5', 'dec_close3mean_perc10', 'dec_close3mean_perc3', 
       'dec_close3min_perc5', 'dec_close3min_perc10', 'dec_close3min_perc3']

df_container = pd.DataFrame()

counter = 0
len_label = len(tickers)

for icol in tickers:
    counter+=1
    print(f"{counter} of {len_label}")
    df_temp = pd.read_parquet( f"{mypath}//{icol}_sentiment_label.parquet")
    df_temp["ticker"] = icol
    if len(df_container) == 0:
        df_container = df_temp[cols_use].copy()
    else:
        df_container = pd.concat([df_container, df_temp[cols_use]], axis=0, ignore_index=True)

df_container['summary_length'] = df_container['summary'].str.len()
df_container['title_length'] = df_container['title'].str.len()
df_container.to_csv("datas\\news_sentiment_target.csv")
# Out:
# 1 of 5208
# 2 of 5208
# 3 of 5208
# 4 of 5208
# 5 of 5208
# 6 of 5208
# 7 of 5208
# 8 of 5208
# 9 of 5208
# 10 of 5208
# 11 of 5208
# 12 of 5208
# 13 of 5208
# 14 of 5208
# 15 of 5208
# 16 of 5208
# 17 of 5208
# 18 of 5208
# 19 of 5208
# 20 of 5208
# 21 of 5208
# 22 of 5208
# 23 of 5208
# 24 of 5208
# 25 of 5208
# 26 of 5208
# 27 of 5208
# 28 of 5208
# 29 of 5208
# 30 of 5208
# 31 of 5208
# 32 of 5208
# 33 of 5208
# 34 of 5208
# 35 of 5208
# 36 of 5208
# 37 of 5208
# 38 of 5208
# 39 of 5208
# 40 of 5208
# 41 of 5208
# 42 of 5208
# 43 of 5208
# 44 of 5208
# 45 of 5208
# 46 of 5208
# 47 of 5208
# 48 of 5208
# 49 of 5208
# 50 of 5208
# 51 of 5208
# 52 of 5208
# 53 of 5208
# 54 of 5208
# 55 of 5208
# 56 of 5208
# 57 of 5208
# 58 of 5208
# 59 of 5208
# 60 of 5208
# 61 of 5208
# 62 of 5208
# 63 of 5208
# 64 of 5208
# 65 of 5208
# 66 of 5208
# 67 of 5208
# 68 of 5208
# 69 of 5208
# 70 of 5208
# 71 of 5208
# 72 of 5208
# 73 of 5208
# 74 of 5208
# 75 of 5208
# 76 of 5208
# 77 of 5208
# ...

# %%
# df_container['title_length'] = df_container['title'].str.len()
df_container.loc[(df_container['label_close2max'].isnull()==False)].shape
# Out:
# (1026602, 39)

# %%
df_container

# %%
import re

# %%
df_container['summary_clean'] = df_container['summary'].str.replace('[^\w\s]', '', regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\arifn\AppData\Local\Temp\ipykernel_35600\3845893454.py:1: SyntaxWarning: invalid escape sequence '\w'
#   df_container['summary_clean'] = df_container['summary'].str.replace('[^\w\s]', '', regex=True)

# %%
df_container['summary_clean'] = df_container['summary'].map(lambda x: re.sub(r'\W+', '', x))

# %%
df_container['summary_clean'][100009]
# Out:
# 'International Papers IP Q2 earnings decline year on year reflecting lower volumes across its segments'
